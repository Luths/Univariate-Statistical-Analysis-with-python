# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading and previewin out dataset.
credit_df = pd.read_csv('http://tiny.cc/aspnpz')
credit_df.head()
# Out:
#    Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0           0   67    male    2     own             NaN           little
# 1           1   22  female    2     own          little         moderate
# 2           2   49    male    1     own          little              NaN
# 3           3   45    male    2    free          little           little
# 4           4   53    male    2    free          little           little
#
#    Credit amount  Duration              Purpose
# 0           1169         6             radio/TV
# 1           5951        48             radio/TV
# 2           2096        12            education
# 3           7882        42  furniture/equipment
# 4           4870        24                  car

# %%
credit_df['Sex'].value_counts()
# Out:
# male      690
# female    310
# Name: Sex, dtype: int64

# %%
#Bar Chart
credit_df['Saving accounts'].value_counts().plot(kind ='bar');

# %%
# Histogram
plt.hist(credit_df ['Duration'], bins=10, histtype='bar', rwidth=0.9);

# %%
# Pie chart
credit_savings = credit_df['Saving accounts'].value_counts()
credit_savings
# Out:
# little        603
# moderate      103
# quite rich     63
# rich           48
# Name: Saving accounts, dtype: int64

# %%
labels =credit_savings.index.tolist()
labels
# Out:
# ['little', 'moderate', 'quite rich', 'rich']

# %%
plt.pie(credit_savings, labels=labels, autopct='%i%%');

# %%
sns.boxplot(credit_df["Duration"]);

# %%
credit_df['Duration'].describe()
# Out:
# count    1000.000000
# mean       20.903000
# std        12.058814
# min         4.000000
# 25%        12.000000
# 50%        18.000000
# 75%        24.000000
# max        72.000000
# Name: Duration, dtype: float64

# %%
# Find the mean of the Age variable
mean_age = credit_df['Age'].mean()
mean_age
round(mean_age,0)
# Out:
# 36.0

# %%
#Find the median 
median_age = credit_df['Age'].median()
median_age
# Out:
# 33.0

# %%
#Find the mode
mode_age = credit_df['Age'].mode().iloc[0]
mode_age
# Out:
# 27

# %%
credit_df.query('Age==27')
# Out:
#      Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 31           31   27    male    2     own          little           little
# 60           60   27    male    2     own          little         moderate
# 86           86   27  female    2     own          little         moderate
# 117         117   27  female    2    rent             NaN           little
# 124         124   27  female    2    rent             NaN         moderate
# 132         132   27    male    1     own          little              NaN
# 136         136   27    male    2     own            rich              NaN
# 140         140   27    male    0     own            rich             rich
# 142         142   27    male    3     own          little           little
# 197         197   27  female    2    rent        moderate         moderate
# 201         201   27    male    1     own          little           little
# 225         225   27    male    2     own          little              NaN
# 226         226   27    male    2     own            rich         moderate
# 243         243   27  female    2     own          little              NaN
# 255         255   27    male    1     own             NaN         moderate
# 260         260   27    male    2     own          little           little
# 319         319   27  female    1     own          little           little
# 366         366   27    male    2     own          little              NaN
# 388         388   27    male    2     own      quite rich         moderate
# 389         389   27  female    2     own          little              NaN
# 402         402   27    male    2     own          little              NaN
# 403         403   27    male    1     own          little              NaN
# 407         407   27    male    2     own          little           little
# 458         458   27  female    2     own          little           little
# 492         492   27  female    2     own        moderate              NaN
# 500         500   27  female    2     own          little           little
# 505         505   27    male    1     own             NaN              NaN
# 553         553   27    male    2     own        moderate         moderate
# 558         558   27    male    2     own          little           little
# 574         574   27    male    1     own          little         moderate
# 576         576   27  female    2     own          little         moderate
# 578         578   27    male    2     own          little         moderate
# 579         579   27    male    1     own          little              NaN
# 616         616   27    male    3    free             NaN         moderate
# 620         620   27    male    2     own          little         moderate
# 640         640   27  female    0     own          little           little
# 645         645   27    male    2    rent             NaN              NaN
# 665         665   27    male    3     own          little              NaN
# 667         667   27  female    2     own          little              NaN
# 670         670   27    male    1     own        moderate              NaN
# 686         686   27    male    2     own             NaN             rich
# 714         714   27    male    3     own          little         moderate
# 764         764   27    male    2     own        moderate              NaN
# 789         789   27    male    2     own          little           little
# 792         792   27    male    2     own             NaN              NaN
# 820         820   27    male    2     own          little              NaN
# 860         860   27    male    2     own            rich              NaN
# 866         866   27  female    2     own          little           little
# 878         878   27    male    3    free          little           little
# 907         907   27    male    2     own             NaN         moderate
# 999         999   27    male    2     own        moderate         moderate
#
#      Credit amount  Duration              Purpose
# 31            4020        24  furniture/equipment
# 60            1391         9             business
# 86            1295        18  furniture/equipment
# 117           2132        10  furniture/equipment
# 124           1924        18  furniture/equipment
# 132           2708        15  furniture/equipment
# 136           8613        27                  car
# 140            709         6                  car
# 142           3416        27             radio/TV
# 197            951        12  furniture/equipment
# 201           1168        12                  car
# 225           2613        36              repairs
# 226          10961        48             radio/TV
# 243           1185        12             business
# 255           7418        60             radio/TV
# 260           1657        12  furniture/equipment
# 319           3643        15  furniture/equipment
# 366           3850        18                  car
# 388           2326        15             business
# 389           1449         9             business
# 402           8648        24             business
# 403            802        14                  car
# 407           1053        15             radio/TV
# 458            343         6  domestic appliances
# 492           1237         6             radio/TV
# 500           3123        24                  car
# 505           1309        10                  car
# 553           1995        12                  car
# 558           3552        24  furniture/equipment
# 574           1082         9             radio/TV
# 576           2930        12             radio/TV
# 578           2820        36                  car
# 579            937        24            education
# 616           9157        60             radio/TV
# 620           3652        21             business
# 640            750        18            education
# 645           7980        36             business
# 665           6314        24      vacation/others
# 667           3609        48             business
# 670           4139        24             business
# 686           1347        10             radio/TV
# 714          14027        60                  car
# 764           2463        24                  car
# 789           5998        40            education
# 792           1221         6  furniture/equipment
# 820           1101        12                  car
# 860           5804        24                  car
# 866           2389        18             radio/TV
# 878           1422         9                  car
# 907           3711        36            education
# 999           4576        45                  car

# %%
credit_df["Credit amount"].var()
# Out:
# 7967843.470906904

# %%
credit_df["Credit amount"].std()
# Out:
# 2822.73687596044

# %%
credit_df_max = credit_df["Credit amount"].max()
credit_df_min = credit_df["Credit amount"].min()
credit_df_max - credit_df_min
# Out:
# 18174

# %%
credit_df["Credit amount"].quantile([0.25,0.5,0.75])
# Out:
# 0.25    1365.50
# 0.50    2319.50
# 0.75    3972.25
# Name: Credit amount, dtype: float64

# %%
credit_df["Credit amount"].skew()
# Out:
# 1.9496276798326209

# %%
credit_df["Credit amount"].describe()
# Out:
# count     1000.000000
# mean      3271.258000
# std       2822.736876
# min        250.000000
# 25%       1365.500000
# 50%       2319.500000
# 75%       3972.250000
# max      18424.000000
# Name: Credit amount, dtype: float64
